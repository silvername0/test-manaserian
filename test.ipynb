# %% [markdown]
# <a href="https://colab.research.google.com/github/silvername0/test-manaserian/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импортирование необходимых библиотек
import pandas as pd

# Загрузка данных из CSV файла
data = pd.read_csv('data.csv')

# Рассчет метрик
data['Delivery Rate'] = (data['Доставлено'] / data['Отправлено']) * 100
data['Open Rate'] = (data['Открытия'] / data['Доставлено']) * 100
data['Click to Open Rate'] = (data['Клики'] / data['Открытия']) * 100
data['Unsubscribe Rate'] = (data['Отписки'] / data['Отправлено']) * 100

# Создание таблицы метрик
metrics_table = data[['День недели', 'Тема письма ',  'Delivery Rate', 'Open Rate', 'Click to Open Rate', 'Unsubscribe Rate']]

# Отображение таблицы метрик
from IPython.display import display
display(metrics_table)
# Out:
#      День недели     Тема письма   Delivery Rate  Open Rate  \
# 0              4  Тема письма 115      95.000044  14.409956
# 1              3  Тема письма 116      95.000056  13.980015
# 2              4  Тема письма 117      95.000027  15.949996
# 3              5  Тема письма 118      95.000006  16.320010
# 4              5  Тема письма 119      94.999945  14.410008
# ..           ...              ...            ...        ...
# 213            2  Тема письма 110      95.000018  14.000042
# 214            4  Тема письма 111      95.000022  13.999965
# 215            4  Тема письма 112      95.000015  13.999996
# 216            1  Тема письма 113      95.000021  15.949981
# 217            5  Тема письма 114      95.000060  16.319949
#
#      Click to Open Rate  Unsubscribe Rate
# 0              3.899810          0.655565
# 1              7.200451          0.655430
# 2             11.999888          0.655487
# 3              9.000039          0.655503
# 4              8.400157          0.655471
# ..                  ...               ...
# 213            3.900477          0.655483
# 214            7.200319          0.655507
# 215           11.999937          0.655499
# 216            8.999718          0.655565
# 217            8.399821          0.655527
#
# [218 rows x 6 columns]

# %% [markdown]
# # Новый раздел

# %%
# Вычисление лучшей темы для рассылки
best_subject = data.groupby('Тема письма ')['Open Rate'].mean().idxmax() # Ищем тему письма с максимальным средним значением Open Rate
best_subject_rate = data.groupby('Тема письма ')['Open Rate'].mean().max() # Ищем самый высокий средний показатель Open Rate для темы письма

# Вычисление лечшего дня недели для рассылки
best_day = data.groupby('День недели')['Open Rate'].mean().idxmax() # Ищем день недели с максимальным средним значением Open Rate
best_day_rate = data.groupby('День недели')['Open Rate'].mean().max() # Ищем самый высокий средний показатель Open Rate из дней недели

week = ['0','понедельник', 'вторник', 'среда', 'четверг', 'пятница', 'суббота', 'воскресенье']

print(f"Лучшая тема для рассылки: {best_subject} с Open Rate {best_subject_rate:.2f}%")
print(f"Лучший день недели для рассылки: {week[best_day]} с Open Rate {best_day_rate:.2f}%")
# Out:
# Лучшая тема для рассылки: Тема письма 1 с Open Rate 20.00%
# Лучший день недели для рассылки: среда с Open Rate 14.33%
